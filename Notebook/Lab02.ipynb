# %% [markdown]
# <a href="https://colab.research.google.com/github/milaneso69/ECBD-ALEJANDROARENAS/blob/main/Lab02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random

# %%
publicaciones = 1000000

# %%
influencer = [
    "Ibai Llanos", "AuronPlay", "TheGrefg", "ElRubius", "Staxx",
    "Debor", "Plex", "Luisito Comunica", "Willirex", "Vegetta777"
]

tipo_post = [
    "Naturaleza", "Paisajes", "Aventura", "Sostenibilidad", "Vida Silvestre",
    "Viajes", "Fotografía Macro", "Ecoturismo", "Montaña", "Océanos"
]

# %%
datos = pd.DataFrame ({
    'influencer': [random.choice(influencer) for _ in range(publicaciones)],
    'tipo_post': [random.choice(tipo_post) for _ in range(publicaciones)],
    'likes': [random.randint(1000, 500000) for _ in range(publicaciones)],
    'comentarios': [random.randint(10, 10000) for _ in range(publicaciones)],
    'fecha': [pd.Timestamp('2023-01-01') + pd.Timedelta(days=random.randint(0, 365)) for _ in range(publicaciones)]
})

# %%
df.head()
# Out:
#     influencer   tipo_post   likes  comentarios      fecha
# 0     TheGrefg  Naturaleza  282050         8799 2023-09-06
# 1        Staxx      Viajes  223720         5199 2023-07-09
# 2    AuronPlay     Montaña  356345         2054 2023-02-13
# 3  Ibai Llanos     Océanos  189028         1313 2023-08-07
# 4         Plex  Naturaleza  475295         9370 2023-09-11

# %%
datos.memory_usage(deep=True).sum() /1024**2
# Out:
# np.float64(138.45755767822266)
