# %% [markdown]
# <a href="https://colab.research.google.com/github/milaneso69/ECBD-ALEJANDROARENAS/blob/main/Lab03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url="https://raw.githubusercontent.com/Yorko/mlcourse.ai/main/data/telecom_churn.csv"

# %%
df=pd.read_csv(url)

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
#Mostrar Columnas
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
#Mostrar la dimensión
df.ndim
# Out:
# 2

# %%
#Mostramos la cantidad de registros

# %%
df.info
# Out:
# <bound method DataFrame.info of      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
# ...

# %%
#Muestra info estadística de los datos numericos
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
df.describe(include=["object","bool"])
# Out:
#        State International plan Voice mail plan  Churn
# count   3333               3333            3333   3333
# unique    51                  2               2      2
# top       WV                 No              No  False
# freq     106               3010            2411   2850

# %%
#Muestra los últimos 5
df.tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df.sample(3)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 2493    KY              21        415                 No              No
# 864     CT             155        510                 No              No
# 2695    WI              72        408                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 2493                      0               92.6               95
# 864                       0              165.4              108
# 2695                      0              179.9              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 2493             15.74              161.9               70             13.76
# 864              28.12              183.7              103             15.61
# 2695             30.58              149.8              112             12.73
#
#       Total night minutes  Total night calls  Total night charge  \
# ...

# %%
df["State"]
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: State, Length: 3333, dtype: object

# %%
#Muestra la información del índice seleccionado
df.loc[0]
# Out:
# State                        KS
# Account length              128
# Area code                   415
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        25
# Total day minutes         265.1
# Total day calls             110
# Total day charge          45.07
# Total eve minutes         197.4
# Total eve calls              99
# Total eve charge          16.78
# Total night minutes       244.7
# Total night calls            91
# Total night charge        11.01
# Total intl minutes         10.0
# Total intl calls              3
# Total intl charge           2.7
# Customer service calls        1
# Churn                     False
# Name: 0, dtype: object

# %%
df.loc[[20,30]]
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 20    FL             147        415                 No              No
# 30    IL             142        415                 No              No
#
#     Number vmail messages  Total day minutes  Total day calls  \
# 20                      0              155.1              117
# 30                      0               84.8               95
#
#     Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 20             26.37              239.7               93             20.37
# 30             14.42              136.7               63             11.62
#
#     Total night minutes  Total night calls  Total night charge  \
# 20                208.8                133                9.40
# 30                250.5                148               11.27
#
#     Total intl minutes  Total intl calls  Total intl charge  \
# 20                10.6                 4               2.86
# ...

# %%
df["Churn"]=df["Churn"].asType("int64")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_31882/1066859364.py in <cell line: 0>()
# ----> 1 df["Churn"]=df["Churn"].asType("int64")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'Series' object has no attribute 'asType'

# %%
df["Churn"]
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3328    False
# 3329    False
# 3330    False
# 3331    False
# 3332    False
# Name: Churn, Length: 3333, dtype: bool
